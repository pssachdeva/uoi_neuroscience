# %%
import h5py
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
positions = loadmat('/Users/psachdeva/data/hc6/Bon/bonpos10.mat', struct_as_record=False)
spikes = loadmat('/Users/psachdeva/data/hc6/Bon/bonspikes10.mat', struct_as_record=False)

# %%
epoch = 6
data = f['pos'][0, 9][0, epoch][0, 0].data
plt.plot(data[:, 1], data[:, 2])

# %%
spikes['spikes'][0, 9][0, epoch][0, 10][0, 0][0, 0]
