# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import loadmat

# %matplotlib inline

# %%
data = loadmat('DynRip.cchspct.6oct.100hz.mat')
spct = data['spct']

# %%
spct.shape
# Out:
# (100, 89934)

# %%
fig, ax = plt.subplots(figsize=(20, 4))
ax.imshow(spct, aspect=100)

# %%
fig, ax = plt.subplots(figsize=(20, 4))
plt.imshow(spct[:, :2000], cmap='gray')

# %%
spct.shape[1] / 100
# Out:
# 899.34
