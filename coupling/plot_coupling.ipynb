# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from coupling_plot_utils import *
# %matplotlib inline

# %% [markdown]
# # NHP

# %%
indy_path = 'fits/nhp/indy_20160411_01.h5'

# %%
axes = plot_coupling_grid(fits_path=indy_path)

# additional customizations #

# first row: selection ratio
for idx in range(3):
    axes[0, idx].set_xlim([0, 1])
    axes[0, idx].set_ylim([0, 1])
    axes[0, idx].plot([0, 1], [0, 1], color='gray', linewidth=3, zorder=-1)
    axes[0, idx].set_aspect('equal')

    axes[0, idx].set_xticks([0, 1])
    axes[0, idx].set_yticks([])

axes[0, 0].set_yticks([0, 1])

# second row: explained variance
for idx in range(3):
    axes[1, idx].set_xlim([0, 1])
    axes[1, idx].set_ylim([0, 1])
    axes[1, idx].plot([0, 1], [0, 1], color='gray', linewidth=3, zorder=-1)
    axes[1, idx].set_aspect('equal')

    axes[1, idx].set_xticks([0, 1])
    axes[1, idx].set_yticks([])

axes[1, 0].set_yticks([0, 1])

# third row: AIC
for idx in range(3):
    axes[2, idx].set_xlim([-3000, 500])
    axes[2, idx].set_ylim([-3000, 500])
    axes[2, idx].plot([-3000, 500], [-3000, 500], color='gray', linewidth=3, zorder=-1)
    axes[2, idx].set_aspect('equal')

    axes[2, idx].set_xticks([])
    axes[2, idx].set_yticks([])

# fourth row: BIC
for idx in range(3):
    axes[3, idx].set_xlim([-3000, 500])
    axes[3, idx].set_ylim([-3000, 500])
    axes[3, idx].plot([-3000, 500], [-3000, 500], color='gray', linewidth=3, zorder=-1)
    axes[3, idx].set_aspect('equal')

    axes[3, idx].set_xticks([])
    axes[3, idx].set_yticks([])

# row labels
axes[0, 0].set_title(r'\textbf{UoI, $R^2$}', fontsize=27)
axes[0, 1].set_title(r'\textbf{UoI, AIC}', fontsize=27)
axes[0, 2].set_title(r'\textbf{UoI, BIC}', fontsize=27)

# column labels
axes[0, 0].set_ylabel(
    r'\textbf{Selection}' '\n' r'\textbf{Ratio}', fontsize=27,
    labelpad=-10
)
axes[1, 0].set_ylabel(
    r'\textbf{Explained}' '\n' r'\textbf{Variance}', fontsize=27,
    labelpad=-10
)
axes[2, 0].set_ylabel(r'\textbf{AIC}', fontsize=27)
axes[3, 0].set_ylabel(r'\textbf{BIC}', fontsize=27)

# overall title
plt.gcf().text(
    x=0.55, y=1.02,
    s=r'\textbf{M1 (Indy)}',
    horizontalalignment='center',
    verticalalignment='center',
    fontsize=35
)

plt.tight_layout(h_pad=0., w_pad=0.)
plt.savefig('nhp_indy_20160411_01.pdf', bbox_inches='tight')

# %% [markdown]
# # ECoG, High-Gamma

# %%
ecog_path = 'fits/ecog/ecog_HG.h5'

# %%
axes = plot_coupling_grid(fits_path=ecog_path)

# additional customizations #

# first row: selection ratio
for idx in range(3):
    axes[0, idx].set_xlim([0, 1])
    axes[0, idx].set_ylim([0, 1])
    axes[0, idx].plot([0, 1], [0, 1], color='gray', linewidth=3, zorder=-1)
    axes[0, idx].set_aspect('equal')

    axes[0, idx].set_xticks([0, 1])
    axes[0, idx].set_yticks([])

axes[0, 0].set_yticks([0, 1])

# second row: explained variance
for idx in range(3):
    axes[1, idx].set_xlim([0.9, 1])
    axes[1, idx].set_ylim([0.9, 1])
    axes[1, idx].plot([0, 1], [0, 1], color='gray', linewidth=3, zorder=-1)
    axes[1, idx].set_aspect('equal')

    axes[1, idx].set_xticks([0.9, 1])
    axes[1, idx].set_xticklabels(['.9', 1])
    axes[1, idx].set_yticks([])

axes[1, 0].set_yticks([.9, 1])
axes[1, 0].set_yticklabels(['.9', 1])

# third row: AIC
for idx in range(3):
    axes[2, idx].set_xlim([-4000, 0])
    axes[2, idx].set_ylim([-4000, 0])
    axes[2, idx].plot([-4000, 0], [-4000, 0], color='gray', linewidth=3, zorder=-1)
    axes[2, idx].set_aspect('equal')

    axes[2, idx].set_xticks([])
    axes[2, idx].set_yticks([])

# fourth row: BIC
for idx in range(3):
    axes[3, idx].set_xlim([-4000, 0])
    axes[3, idx].set_ylim([-4000, 0])
    axes[3, idx].plot([-4000, 0], [-4000, 0], color='gray', linewidth=3, zorder=-1)
    axes[3, idx].set_aspect('equal')

    axes[3, idx].set_xticks([])
    axes[3, idx].set_yticks([])

# row labels
axes[0, 0].set_title(r'\textbf{UoI, $R^2$}', fontsize=27)
axes[0, 1].set_title(r'\textbf{UoI, AIC}', fontsize=27)
axes[0, 2].set_title(r'\textbf{UoI, BIC}', fontsize=27)

# column labels
axes[0, 0].set_ylabel(
    r'\textbf{Selection}' '\n' r'\textbf{Ratio}', fontsize=27,
    labelpad=-10
)
axes[1, 0].set_ylabel(
    r'\textbf{Explained}' '\n' r'\textbf{Variance}', fontsize=27,
    labelpad=-15
)
axes[2, 0].set_ylabel(r'\textbf{AIC}', fontsize=27)
axes[3, 0].set_ylabel(r'\textbf{BIC}', fontsize=27)

# overall title
plt.gcf().text(
    x=0.55, y=1.02,
    s=r'\textbf{A1, }$\mu$\textbf{ECoG (H}$\boldsymbol{\gamma}$\textbf{)}' ,
    horizontalalignment='center',
    verticalalignment='center',
    fontsize=35
)

plt.tight_layout(h_pad=0.5, w_pad=0.)
plt.savefig('ecog_hg.pdf', bbox_inches='tight')

# %% [markdown]
# # PVC11

# %% [markdown]
# ## Monkey 1

# %%
monkey1_path = 'fits/pvc11/monkey1.h5'

# %%
axes = plot_coupling_grid(fits_path=monkey1_path)

# additional customizations #

# first row: selection ratio
for idx in range(3):
    axes[0, idx].set_xlim([0, 1])
    axes[0, idx].set_ylim([0, 1])
    axes[0, idx].plot([0, 1], [0, 1], color='gray', linewidth=3, zorder=-1)
    axes[0, idx].set_aspect('equal')

    axes[0, idx].set_xticks([0, 1])
    axes[0, idx].set_yticks([])

axes[0, 0].set_yticks([0, 1])

# second row: explained variance
for idx in range(3):
    axes[1, idx].set_xlim([0., 1])
    axes[1, idx].set_ylim([0., 1])
    axes[1, idx].plot([0, 1], [0, 1], color='gray', linewidth=3, zorder=-1)
    axes[1, idx].set_aspect('equal')

    axes[1, idx].set_xticks([0, 1])
    axes[1, idx].set_yticks([])

axes[1, 0].set_yticks([0, 1])

# third row: AIC
for idx in range(3):
    axes[2, idx].set_xlim([-1000, 600])
    axes[2, idx].set_ylim([-1000, 600])
    axes[2, idx].plot([-1000, 600], [-1000, 600], color='gray', linewidth=3, zorder=-1)
    axes[2, idx].set_aspect('equal')

    axes[2, idx].set_xticks([])
    axes[2, idx].set_yticks([])

# fourth row: BIC
for idx in range(3):
    axes[3, idx].set_xlim([-1000, 600])
    axes[3, idx].set_ylim([-1000, 600])
    axes[3, idx].plot([-1000, 600], [-1000, 600], color='gray', linewidth=3, zorder=-1)
    axes[3, idx].set_aspect('equal')

    axes[3, idx].set_xticks([])
    axes[3, idx].set_yticks([])

# row labels
axes[0, 0].set_title(r'\textbf{UoI, $R^2$}', fontsize=27)
axes[0, 1].set_title(r'\textbf{UoI, AIC}', fontsize=27)
axes[0, 2].set_title(r'\textbf{UoI, BIC}', fontsize=27)

# column labels
axes[0, 0].set_ylabel(
    r'\textbf{Selection}' '\n' r'\textbf{Ratio}', fontsize=27,
    labelpad=-10
)
axes[1, 0].set_ylabel(
    r'\textbf{Explained}' '\n' r'\textbf{Variance}', fontsize=27,
    labelpad=-10
)
axes[2, 0].set_ylabel(r'\textbf{AIC}', fontsize=27)
axes[3, 0].set_ylabel(r'\textbf{BIC}', fontsize=27)

# overall title
plt.gcf().text(
    x=0.55, y=1.02,
    s=r'\textbf{PVC Monkey 1}',
    horizontalalignment='center',
    verticalalignment='center',
    fontsize=35
)

plt.tight_layout(h_pad=0., w_pad=0.)
plt.savefig('pvc11_monkey1.pdf', bbox_inches='tight')

# %% [markdown]
# ## Monkey 2

# %%
monkey2_path = 'fits/pvc11/monkey2.h5'

# %%
axes = plot_coupling_grid(fits_path=monkey2_path)

# additional customizations #

# first row: selection ratio
for idx in range(3):
    axes[0, idx].set_xlim([0, 1])
    axes[0, idx].set_ylim([0, 1])
    axes[0, idx].plot([0, 1], [0, 1], color='gray', linewidth=3, zorder=-1)
    axes[0, idx].set_aspect('equal')

    axes[0, idx].set_xticks([0, 1])
    axes[0, idx].set_yticks([])

axes[0, 0].set_yticks([0, 1])

# second row: explained variance
for idx in range(3):
    axes[1, idx].set_xlim([0., 1])
    axes[1, idx].set_ylim([0., 1])
    axes[1, idx].plot([0, 1], [0, 1], color='gray', linewidth=3, zorder=-1)
    axes[1, idx].set_aspect('equal')

    axes[1, idx].set_xticks([0, 1])
    axes[1, idx].set_yticks([])

axes[1, 0].set_yticks([0, 1])

# third row: AIC
for idx in range(3):
    axes[2, idx].set_xlim([-1000, 600])
    axes[2, idx].set_ylim([-1000, 600])
    axes[2, idx].plot([-1000, 600], [-1000, 600], color='gray', linewidth=3, zorder=-1)
    axes[2, idx].set_aspect('equal')

    axes[2, idx].set_xticks([])
    axes[2, idx].set_yticks([])

# fourth row: BIC
for idx in range(3):
    axes[3, idx].set_xlim([-1000, 600])
    axes[3, idx].set_ylim([-1000, 600])
    axes[3, idx].plot([-1000, 600], [-1000, 600], color='gray', linewidth=3, zorder=-1)
    axes[3, idx].set_aspect('equal')

    axes[3, idx].set_xticks([])
    axes[3, idx].set_yticks([])

# row labels
axes[0, 0].set_title(r'\textbf{UoI, $R^2$}', fontsize=27)
axes[0, 1].set_title(r'\textbf{UoI, AIC}', fontsize=27)
axes[0, 2].set_title(r'\textbf{UoI, BIC}', fontsize=27)

# overall title
plt.gcf().text(
    x=0.55, y=1.02,
    s=r'\textbf{PVC Monkey 2}',
    horizontalalignment='center',
    verticalalignment='center',
    fontsize=35
)

plt.tight_layout(h_pad=0., w_pad=0.)
plt.savefig('pvc11_monkey2.pdf', bbox_inches='tight')

# %% [markdown]
# ## Monkey 3

# %%
monkey3_path = 'fits/pvc11/monkey3.h5'

# %%
axes = plot_coupling_grid(fits_path=monkey3_path)

# additional customizations #

# first row: selection ratio
for idx in range(3):
    axes[0, idx].set_xlim([0, 1])
    axes[0, idx].set_ylim([0, 1])
    axes[0, idx].plot([0, 1], [0, 1], color='gray', linewidth=3, zorder=-1)
    axes[0, idx].set_aspect('equal')

    axes[0, idx].set_xticks([0, 1])
    axes[0, idx].set_yticks([])

axes[0, 0].set_yticks([0, 1])

# second row: explained variance
for idx in range(3):
    axes[1, idx].set_xlim([0., 1])
    axes[1, idx].set_ylim([0., 1])
    axes[1, idx].plot([0, 1], [0, 1], color='gray', linewidth=3, zorder=-1)
    axes[1, idx].set_aspect('equal')

    axes[1, idx].set_xticks([0, 1])
    axes[1, idx].set_yticks([])

axes[1, 0].set_yticks([0, 1])

# third row: AIC
for idx in range(3):
    axes[2, idx].set_xlim([-1000, 600])
    axes[2, idx].set_ylim([-1000, 600])
    axes[2, idx].plot([-1000, 600], [-1000, 600], color='gray', linewidth=3, zorder=-1)
    axes[2, idx].set_aspect('equal')

    axes[2, idx].set_xticks([])
    axes[2, idx].set_yticks([])

# fourth row: BIC
for idx in range(3):
    axes[3, idx].set_xlim([-1000, 600])
    axes[3, idx].set_ylim([-1000, 600])
    axes[3, idx].plot([-1000, 600], [-1000, 600], color='gray', linewidth=3, zorder=-1)
    axes[3, idx].set_aspect('equal')

    axes[3, idx].set_xticks([])
    axes[3, idx].set_yticks([])

# row labels
axes[0, 0].set_title(r'\textbf{UoI, $R^2$}', fontsize=27)
axes[0, 1].set_title(r'\textbf{UoI, AIC}', fontsize=27)
axes[0, 2].set_title(r'\textbf{UoI, BIC}', fontsize=27)


# overall title
plt.gcf().text(
    x=0.55, y=1.02,
    s=r'\textbf{PVC Monkey 3}',
    horizontalalignment='center',
    verticalalignment='center',
    fontsize=35
)

plt.tight_layout(h_pad=0., w_pad=0.)
plt.savefig('pvc11_monkey3.pdf', bbox_inches='tight')
