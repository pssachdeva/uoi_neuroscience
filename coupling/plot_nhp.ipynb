# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from coupling_plot_utils import *
# %matplotlib inline

# %% [markdown]
# # Indy 20160411_01

# %%
indy_path = 'fits/nhp/indy_20160411_01.h5'

# %%
axes = plot_coupling_grid(fits_path=indy_path)

# additional customizations

# selection ratio + explained variance unity lines
for idx in range(3):
    axes[idx, 0].plot([0, 1], [0, 1], color='gray', linewidth=3, zorder=-1)
    axes[idx, 1].plot([0, 1], [0, 1], color='gray', linewidth=3, zorder=-1)
    axes[idx, 0].set_xticks([])
    axes[idx, 0].set_yticks([0, 1])
    axes[idx, 1].set_xticks([])
    axes[idx, 1].set_yticks([])

# AIC axes
for idx in range(3):
    axes[idx, 2].plot([-3000, 1000], [-3000, 1000], color='gray', linewidth=3, zorder=-1)
    axes[idx, 2].set_xlim([-3000, 1000])
    axes[idx, 2].set_ylim([-3000, 1000])
    axes[idx, 2].set_aspect('equal')
    axes[idx, 2].set_xticks([])
    axes[idx, 2].set_yticks([])

# BIC axes
for idx in range(3):
    axes[idx, 3].plot([-3000, 1000], [-3000, 1000], color='gray', linewidth=3, zorder=-1)
    axes[idx, 3].set_xlim([-3000, 1000])
    axes[idx, 3].set_ylim([-3000, 1000])
    axes[idx, 3].set_aspect('equal')
    axes[idx, 3].set_xticks([])
    axes[idx, 3].set_yticks([])

# labels for selection ratio and explained variance
axes[2, 0].set_xticks([0, 1])
axes[2, 0].set_xticklabels([0, 1])
axes[2, 1].set_xticks([0, 1])
axes[2, 1].set_xticklabels([0, 1])

plt.gcf().text(
    x=0.5, y=1.03,
    s=r'\textbf{M1, Indy (04/11/2016--01)}',
    horizontalalignment='center',
    verticalalignment='center',
    fontsize=27
)
plt.tight_layout(h_pad=0., w_pad=0.)
plt.savefig('indy_20160411_01.pdf', bbox_inches='tight')
